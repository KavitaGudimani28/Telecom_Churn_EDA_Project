# %% [markdown]
# <a href="https://colab.research.google.com/github/KavitaGudimani28/Telecom_Churn_EDA_Project/blob/main/Kavita_G__Telecom_Churn_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %%
#importing libraries
import pandas as pd
import numpy as np
import ast

# %%
#Mounting Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing CSV from the drive and converting csv to pandas df
df = pd.read_csv('/content/drive/MyDrive/Copy of Telecom Churn.csv')

# %%
# Displaying 1st five rows
df.head(5).T
# Out:
#                             0      1      2      3      4
# State                      KS     OH     NJ     OH     OK
# Account length            128    107    137     84     75
# Area code                 415    415    415    408    415
# International plan         No     No     No    Yes    Yes
# Voice mail plan           Yes    Yes     No     No     No
# Number vmail messages      25     26      0      0      0
# Total day minutes       265.1  161.6  243.4  299.4  166.7
# Total day calls           110    123    114     71    113
# Total day charge        45.07  27.47  41.38   50.9  28.34
# Total eve minutes       197.4  195.5  121.2   61.9  148.3
# Total eve calls            99    103    110     88    122
# Total eve charge        16.78  16.62   10.3   5.26  12.61
# Total night minutes     244.7  254.4  162.6  196.9  186.9
# Total night calls          91    103    104     89    121
# Total night charge      11.01  11.45   7.32   8.86   8.41
# ...

# %%
df.head(20).T
# Out:
#                            0      1      2      3      4      5      6   \
# State                      KS     OH     NJ     OH     OK     AL     MA
# Account length            128    107    137     84     75    118    121
# Area code                 415    415    415    408    415    510    510
# International plan         No     No     No    Yes    Yes    Yes     No
# Voice mail plan           Yes    Yes     No     No     No     No    Yes
# Number vmail messages      25     26      0      0      0      0     24
# Total day minutes       265.1  161.6  243.4  299.4  166.7  223.4  218.2
# Total day calls           110    123    114     71    113     98     88
# Total day charge        45.07  27.47  41.38   50.9  28.34  37.98  37.09
# Total eve minutes       197.4  195.5  121.2   61.9  148.3  220.6  348.5
# Total eve calls            99    103    110     88    122    101    108
# Total eve charge        16.78  16.62   10.3   5.26  12.61  18.75  29.62
# ...

# %%
df.describe(include='all').T
# Out:
#                          count unique    top  freq        mean        std  \
# State                     3333     51     WV   106         NaN        NaN
# Account length          3333.0    NaN    NaN   NaN  101.064806  39.822106
# Area code               3333.0    NaN    NaN   NaN  437.182418   42.37129
# International plan        3333      2     No  3010         NaN        NaN
# Voice mail plan           3333      2     No  2411         NaN        NaN
# Number vmail messages   3333.0    NaN    NaN   NaN     8.09901  13.688365
# Total day minutes       3333.0    NaN    NaN   NaN  179.775098  54.467389
# Total day calls         3333.0    NaN    NaN   NaN  100.435644  20.069084
# Total day charge        3333.0    NaN    NaN   NaN   30.562307   9.259435
# Total eve minutes       3333.0    NaN    NaN   NaN  200.980348  50.713844
# Total eve calls         3333.0    NaN    NaN   NaN  100.114311  19.922625
# Total eve charge        3333.0    NaN    NaN   NaN    17.08354   4.310668
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %%
plt.bar(df.State,df.index)
plt.figure(figsize=(20, 20))
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.bar(df.State,df.Churn)
plt.xlabel('Month Number')
plt.ylabel("Total Profit")
plt.title("Profit over Month")
plt.show()

# %%
plt.bar(df.State,df.index)
# Out:
# <BarContainer object of 3333 artists>

# %%
plt.figure(figsize = (20,5))
plt.bar(df['Total day calls'],df.Churn)
plt.xlabel('Total day calls')
plt.ylabel("Churn")

plt.show()

# %%
sns.distplot(df['Total day calls'], hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Total day minutes'], hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.Churn.corr(df['Total day calls'])
# Out:
# 0.0184593116085769

# %%
df.Churn.corr(df['Total night calls'])
# Out:
# 0.006141203007399705

# %%
df.Churn.corr(df['Total intl calls'])
# Out:
# -0.05284433577413811

# %%
df.Churn.corr(df['Customer service calls'])
# Out:
# 0.20874999878379405

# %%
df.Churn.corr(df['Total day minutes'])
# Out:
# 0.20515082926139028

# %%
df.Churn.corr(df['Total night minutes'])
# Out:
# 0.03549285342127401

# %%
#Encoding
df["Int_Churn"] = df["Churn"].astype(int)
df["Int_Voice_mail_plan"] = df["Voice mail plan"].map({'Yes': 1, 'No': 0})
df["Int_International_plan"] = df["International plan"].map({'Yes': 1, 'No': 0})

# %%
df.head(11).T
# Out:
#                            0      1      2      3      4      5      6   \
# State                      KS     OH     NJ     OH     OK     AL     MA
# Account length            128    107    137     84     75    118    121
# Area code                 415    415    415    408    415    510    510
# International plan         No     No     No    Yes    Yes    Yes     No
# Voice mail plan           Yes    Yes     No     No     No     No    Yes
# Number vmail messages      25     26      0      0      0      0     24
# Total day minutes       265.1  161.6  243.4  299.4  166.7  223.4  218.2
# Total day calls           110    123    114     71    113     98     88
# Total day charge        45.07  27.47  41.38   50.9  28.34  37.98  37.09
# Total eve minutes       197.4  195.5  121.2   61.9  148.3  220.6  348.5
# Total eve calls            99    103    110     88    122    101    108
# Total eve charge        16.78  16.62   10.3   5.26  12.61  18.75  29.62
# ...

# %%
plt.figure(figsize = (15, 12))
sns.heatmap(df.corr(), cmap="RdYlBu", annot=True, fmt=".1f")
plt.show()

# %%
plt.figure(figsize = (15, 12))
dataplot =sns.heatmap(df.corr(),cmap='YlGnBu',annot=True)
plt.show()

# %%
corr=df.corr()
f,ax=plt.subplots(figsize=(20,10))
mask=np.triu(np.ones_like(corr,dtype=bool))
cmap=sns.diverging_palette(230,20,as_cmap=True)
sns.heatmap(corr,annot=True,mask=mask,cmap=cmap)

# %%
plt.hist(df['Total day calls'].values, color='green')
plt.xlabel('Total day calls')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
def df_scattr(a,b):
    fig = plt.figure()
    fig = sns.lmplot(a,b, data=df,fit_reg=False)
    plt.xlabel(a,fontsize= 14)
    plt.ylabel(b,fontsize= 14)
    plt.xticks(fontsize=10, rotation=90)
    plt.yticks(fontsize=10)
    plt.title("{A} and {B} Scatter Plot".format(A=a,B=b),fontsize = 16)
    plt.show()

# %%
df_scattr('Total day calls','Total day charge')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
columname = df.columns[(df.dtypes=="float64")|(df.dtypes=="int64")].tolist()
for i in columname:
    plt.figure()
    plt.clf() 
    sns.boxplot(df[i],palette="deep")
    plt.title(i)
    plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
df_scattr('Total night charge','Total night minutes')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_scattr('Total intl charge','Total intl minutes')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_scattr('Total day charge','Total day minutes')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_scattr('Total eve charge','Total eve minutes')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def df_scattr(a,b,df,c,d,e):
    plt.figure(figsize=(20,10))
    sns.scatterplot(a,b, data=df,hue=e).set(title=f'{c} and {d} Scatter Plot')
    plt.show()

df_scattr(df['State'],df['Total day charge'],df,'State','Total day charges','Churn')
#sns.scatterplot(x="State", y = "Total day charge" , hue="Churn", data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Sum'] = df['Total night calls'] + df['Total day calls'] + df['Total intl calls'] +df['Customer service calls']
df['Sum']
# Out:
# 0       205
# 1       230
# 2       223
# 3       169
# 4       240
#        ...
# 3328    168
# 3329    187
# 3330    208
# 3331    254
# 3332    194
# Name: Sum, Length: 3333, dtype: int64

# %%
sns.scatterplot(x='Sum',y='State',hue='Churn',data=df)
plt.figure(figsize=(20, 10))
plt.show()

# %%
s1=df['State'].unique()
s2=df.groupby(['State'])['Churn'].mean()

plt.rcParams['figure.figsize'] = (20, 8)

plt.plot(s1,s2,color='m', marker='o', linewidth=2, markersize=10)

plt.title(" States churn rate", fontsize = 25)
plt.xlabel('state', fontsize = 15)
plt.ylabel('churn rate', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (12, 7)
# color = plt.cm.copper(np.linspace(0, 0.5, 20))
((df.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = False).head(20).plot.bar(color = ['b'])
plt.title(" State with most churn percentage", fontsize = 25)
plt.xlabel('state', fontsize = 20)
plt.ylabel('percentage', fontsize = 20)
plt.show()

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.shape
# Out:
# (3333, 23)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn', 'Int_Churn', 'Int_Voice_mail_plan', 'Int_International_plan'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                       int64
# Int_Churn                   int64
# Int_Voice_mail_plan         int64
# Int_International_plan      int64
# dtype: object

# %%
def initial_overview(dataset):
    
    '''
    This function allows to view initial overview of the data.
    Such as number of rows, features and feature labels, 
    is/are there any missing value/s in the data set?,
    unique values in the dataset


    '''
    
    print('Overview of the Dataset')

    #shape of the Dataset
    print('\n Shape:',df.shape)

    #Rows in the dataset
    print("Rows:", df.shape[0])

    #Column or Feature in the dataset
    print("\nNumber of features:", df.shape[1])
    print("\nFeatures:")
    print(df.columns.tolist())

    #missing value
    missing_value = df.isnull().sum().values.sum()

    if missing_value == 0:
      print('\n Missing Values: No Missing Values')
    else:
      print('\n Missing Values:', missing_value)

    #unique value

    print("\n Unique values:")
    print(df.nunique())

     #Data Type
    print("\n Datatype:")
    print(df.dtypes)

# %%
initial_overview(df)
# Out:
# Overview of the Dataset
#
#  Shape: (3333, 23)
# Rows: 3333
#
# Number of features: 23
#
# Features:
# ['State', 'Account length', 'Area code', 'International plan', 'Voice mail plan', 'Number vmail messages', 'Total day minutes', 'Total day calls', 'Total day charge', 'Total eve minutes', 'Total eve calls', 'Total eve charge', 'Total night minutes', 'Total night calls', 'Total night charge', 'Total intl minutes', 'Total intl calls', 'Total intl charge', 'Customer service calls', 'Churn', 'Int_Churn', 'Int_Voice_mail_plan', 'Int_International_plan']
#
#  Missing Values: No Missing Values
#
#  Unique values:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# ...
